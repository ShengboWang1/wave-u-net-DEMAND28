# %%
# !pip3 install json5 pesq pystoi tqdm librosa
# Out:
# ...
#   Created wheel for pesq: filename=pesq-0.0.3-cp37-cp37m-linux_x86_64.whl size=209939 sha256=6a87015c725250022abd2c3441768320d73c7065594ffc364eb268d0141794d6
#   Stored in directory: /root/.cache/pip/wheels/6d/c0/a7/d8fa9795dd9cd1554510e22e83ff3c55cc55e916e2d251864b
# ...
#   Created wheel for pystoi: filename=pystoi-0.3.3-py2.py3-none-any.whl size=7794 sha256=effba804c2726e198a4a57d558954269d1c658a5519adc49b1c7835904ad9052
#   Stored in directory: /root/.cache/pip/wheels/6b/6c/b2/d49af4b7ee4ce275cf2511484b043e09b9cb7ae90c1accb17a
# Successfully built pesq pystoi
# ...

# %%
# !python /content/drive/MyDrive/Forschungsarbeit/Wave-U-Net-DEMAND_28/train.py -C /content/drive/MyDrive/Forschungsarbeit/Wave-U-Net-DEMAND_28/config/train/train.json
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 40 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 2021-06-26 18:41:37.161784: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Configurations are as follows:
# {
#   seed: 0,
#   description: "...des",
#   root_dir: "/content/drive/MyDrive/Forschungsarbeit/Wave-U-Net-DEMAND_28/Experiments_30_04",
#   cudnn_deterministic: false,
#   trainer: {
#     module: "trainer.trainer",
#     main: "Trainer",
#     epochs: 1200,
#     save_checkpoint_interval: 10,
#     validation: {
#       interval: 10,
# ...
